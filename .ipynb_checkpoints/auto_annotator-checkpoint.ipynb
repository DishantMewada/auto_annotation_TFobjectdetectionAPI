# %%
# Import Module
from tkinter import *
 
# create root window
root = Tk()
 
# root window title and dimension
root.title("Welcome to GeekForGeeks")
# Set geometry (widthxheight)
root.geometry('350x200')
 
# all widgets will be here
# Execute Tkinter
root.mainloop()

# %%
# Import Module
from tkinter import *
 
# create root window
root = Tk()
 
# root window title and dimension
root.title("Welcome to GeekForGeeks")
# Set geometry(widthxheight)
root.geometry('350x200')
 
#adding a label to the root window
lbl = Label(root, text = "Are you a Geek?")
lbl.grid()
 
# Execute Tkinter
root.mainloop()

# %%
# Import Module
from tkinter import *
 
# create root window
root = Tk()
 
# root window title and dimension
root.title("Welcome to GeekForGeeks")
# Set geometry(widthxheight)
root.geometry('350x200')
 
# adding a label to the root window
lbl = Label(root, text = "Are you a Geek?")
lbl.grid()
 
# function to display text when
# button is clicked
def clicked():
    lbl.configure(text = "I just got clicked")
 
# button widget with red color text
# inside
btn = Button(root, text = "Click me" ,
             fg = "red", command=clicked)
# set Button grid
btn.grid(column=1, row=0)
 
# Execute Tkinter
root.mainloop()

# %%
# Import Module
from tkinter import *
import os 
# create root window
root = Tk()
 
# root window title and dimension
root.title("Welcome to GeekForGeeks")
# Set geometry(widthxheight)
root.geometry('350x200')
 
# adding a label to the root window
lbl = Label(root, text = "Are you a Geek?")
lbl.grid()
 
# adding Entry Field
txt = Entry(root, width=10)
txt.grid(column =1, row =0)
 
 
# function to display user text when
# button is clicked
def open():
    os.system("nautilus")

def clicked():
 
    res = "You wrote " + txt.get()
    lbl.configure(text = res)
 
# button widget with red color text inside
btn = Button(root, text = "Click me" ,
             fg = "red",  font=("Ariel", 9, "bold"), command=open)
# Set Button Grid
btn.grid(column=2, row=0)
 
# Execute Tkinter
root.mainloop()

# %%
# Python program to create
# a file explorer in Tkinter
  
# import all components
# from the tkinter library
from tkinter import *
  
# import filedialog module
from tkinter import filedialog
  
# Function for opening the
# file explorer window
def browseFiles():
    filename = filedialog.askopenfilename(initialdir = "/",
                                          title = "Select a File",
                                          filetypes = (("Text files",
                                                        "*.jpg*"),
                                                       ("all files",
                                                        "*.*")))
      
    # Change label contents
    label_file_explorer.configure(text="File Opened: "+filename)
      
      
                                                                                                  
# Create the root window
window = Tk()
  
# Set window title
window.title('File Explorer')
  
# Set window size
window.geometry("500x500")
  
#Set window background color
window.config(background = "white")
  
# Create a File Explorer label
label_file_explorer = Label(window,
                            text = "File Explorer using Tkinter",
                            width = 100, height = 4,
                            fg = "blue")
  
      
button_explore = Button(window,
                        text = "Browse Files",
                        command = browseFiles)
  
button_exit = Button(window,
                     text = "Exit",
                     command = exit)
  
# Grid method is chosen for placing
# the widgets at respective positions
# in a table like structure by
# specifying rows and columns
label_file_explorer.grid(column = 1, row = 1)
  
button_explore.grid(column = 1, row = 2)
  
button_exit.grid(column = 1,row = 3)
  
# Let the window wait for any events
window.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from tkinter import filedialog
gui = Tk()
gui.geometry("400x400")
gui.title("FC")

def getFolderPath():
    folder_selected = filedialog.askdirectory()
    folderPath.set(folder_selected)
    folder = folderPath.get()
    print("Doing stuff with folder", folder)

folderPath = StringVar()
a = Label(gui ,text="Enter name")
a.grid(row=0,column = 0)
E = Entry(gui,textvariable=folderPath)
E.grid(row=0,column=1)
btnFind = ttk.Button(gui, text="Browse Folder",command=getFolderPath)
btnFind.grid(row=0,column=2)

c = ttk.Button(gui ,text="find", command=doStuff)
c.grid(row=4,column=0)
gui.mainloop()

# %%
from tkinter import *
from tkinter import ttk
from tkinter import filedialog
gui = Tk()
gui.geometry("1000x500")
gui.title("Auto-annotation")

displayPath = Label(gui, text = 'Folder Path', width=112)
displayPath.grid(row=0,column=1)

radioValue = IntVar() 

def getFolderPath():
    folder_selected = filedialog.askdirectory()
    folderPath.set(folder_selected)
    folder = folderPath.get()
    print("Doing stuff with folder", folder)
    displayPath.configure(text = folder)

folderPath = StringVar()
importPath = ttk.Button(gui, text="Import Folder",command=getFolderPath)
importPath.grid(row=0,column=0)

gui.mainloop()
# Out:
# Doing stuff with folder /home/dishant/auto-annotation/images

# %%
import tkinter as tk

root = tk.Tk()

v = tk.IntVar()
v.set(1)  # initializing the choice, i.e. Python

languages = [("Python", 101),
   	     ("Perl", 102),
    	     ("Java", 103),
             ("C++", 104),
             ("C", 105)]

def ShowChoice():
    print(v.get())

tk.Label(root, 
         text="""Choose your favourite 
programming language:""",
         justify = tk.LEFT,
         padx = 20).pack()

for language, val in languages:
     tk.Radiobutton(root, 
                  text=language,
                  indicatoron = 0,
                  width = 20,
                  padx = 20, 
                  variable=v, 
                  command=ShowChoice,
                  value=val).pack(anchor=tk.W)



root.mainloop()
# Out:
# 103

# %%
from tkinter import *
from tkinter import ttk
from tkinter import filedialog
import tkinter as tk

import os

gui = Tk()
gui.geometry("1000x500")
gui.title("Auto-annotation")

finalEntry = {}

prerequisite = Label(gui, text = '0. Install Prerequisite',pady = 10)
prerequisite.grid(row=0,column=0)


def getModel():
    os.system("git clone https://github.com/tensorflow/models.git && cd models && git checkout -f e04dafd04d69053d3733bb91d47d0d95bc2c8199")
    downloadModelStatus = Label(gui, text = 'Complete')
    downloadModelStatus.grid(row=1,column=1)
    
downloadModel = ttk.Button(gui, text="Download Tf-Model",command=getModel,width=20)
downloadModel.grid(row=0,column=1)

downloadModelStatus = Label(gui, text = '')
downloadModelStatus.grid(row=1,column=1)

####

def compileModelFunc():
    os.system("cd ./models/research && protoc object_detection/protos/*.proto --python_out=. && python setup.py build && python setup.py install")
    compileModelStatus = Label(gui, text = 'Complete')
    compileModelStatus.grid(row=1,column=2)
    
compileModel = ttk.Button(gui, text="Compile Model",command=compileModelFunc,width=20)
compileModel.grid(row=0,column=2)

compileModelStatus = Label(gui, text = '')
compileModelStatus.grid(row=1,column=2)

####

path = os.getcwd()

workspace_path = path+"/workspace"
pretrained_model_path = workspace_path+"/pre-trained-models"

def buildDirFunc():
    try:
        os.mkdir(workspace_path)
        os.mkdir(pretrained_model_path)
    except OSError:
        buildDirStatus = Label(gui, text = 'OS Error')
        buildDirStatus.grid(row=1,column=3)
    else:
        buildDirStatus = Label(gui, text = 'Complete')
        buildDirStatus.grid(row=1,column=3)
    
buildDir = ttk.Button(gui, text="Build Dirs",command=buildDirFunc,width=20)
buildDir.grid(row=0,column=3)

buildDirStatus = Label(gui, text = '')
buildDirStatus.grid(row=1,column=3)

####

def installPIPfunc():
    os.system("pip3 install wheel tensorflow-gpu==2.5.0 tf-models-official matplotlib Cython")
    buildPIPStatus = Label(gui, text = 'Complete')
    buildPIPStatus.grid(row=1,column=4)
    
buildPIP = ttk.Button(gui, text="Install PIPs",command=installPIPfunc,width=20)
buildPIP.grid(row=0,column=4)

buildPIPStatus = Label(gui, text = '')
buildPIPStatus.grid(row=1,column=4)

##############################################################
displayPath = Label(gui, text = '/Folder/Path/', width=50,pady = 15)
displayPath.grid(row=2,column=1,columnspan=5)

radioValue = IntVar() 

def getFolderPath():
    folder_selected = filedialog.askdirectory()
    folderPath.set(folder_selected)
    folder = folderPath.get()
    displayPath.configure(text = folder)
    finalEntry["imagesFolder"] = folder


folderPath = StringVar()
importPath = ttk.Button(gui, text="1. Import Folder",command=getFolderPath)
importPath.grid(row=2,column=0)


##############################################################

zoo = [("EfficientDet D0 512x512", "https://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz",4),
       ("EfficientDet D1 640x640", "https://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d1_coco17_tpu-32.tar.gz",5),
       ("EfficientDet D2 768x768", "https://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d2_coco17_tpu-32.tar.gz",6),
       ("EfficientDet D3 896x896", "https://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d3_coco17_tpu-32.tar.gz",7),
       ("EfficientDet D4 1024x1024", "https://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d4_coco17_tpu-32.tar.gz",8),
       ("SSD MobileNet V1 FPN 640x640", "https://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8.tar.gz",9),
       ("SSD MobileNet V2 FPNLite 320x320", "https://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz",10)
      ]

v = tk.IntVar()

def ShowChoice():
    #print(v.get())
    for model, link, index in zoo:
        if index == v.get():
            finalEntry["downloadLink"] = link

tk.Label(gui, 
         text="""2. Choose object detection pretrained-model""",
         justify = tk.LEFT,
         pady = 10).grid(row=3,column=0)


for model, link, index in zoo:
    tk.Radiobutton(gui, 
                   text=model,
                   #indicatoron = 0,
                   width = 30,
                   padx = 20, 
                   variable=v, 
                   command=ShowChoice,
                   value=index).grid(row=index,column=0)
#####################################################################
displayDownloadStatus = Label(gui, text = '', width=50,pady = 15)
displayDownloadStatus.grid(row=11,column=1,columnspan=5)


def downloadPretrainedModelFunc():
    
    print( os.getcwd())
    
    tarName = finalEntry.get('downloadLink').split("/")
    folderTAR = tarName[-1].split(".")
    
    stringForCMD = "cd ./workspace/pre-trained-models && wget --no-check-certificate {0} && tar -zxvf {1}".format(finalEntry.get('downloadLink'),tarName[-1])
    
    os.system(stringForCMD)
    
    displayDownloadStatus = Label(gui, text = 'Complete', width=50,pady = 15)
    displayDownloadStatus.grid(row=11,column=1,columnspan=5)



downloadPretrainedModel = ttk.Button(gui, text="3. Download the model",command=downloadPretrainedModelFunc)
downloadPretrainedModel.grid(row=11,column=0)



gui.mainloop()
# Out:
# Requirement already satisfied: jupyter in ./jupyter-venv/lib/python3.8/site-packages (1.0.0)
# Collecting ibm-watson
#   Downloading ibm-watson-5.3.0.tar.gz (412 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting tensorflow-gpu==2.5.0
#   Downloading tensorflow_gpu-2.5.0-cp38-cp38-manylinux2010_x86_64.whl (454.4 MB)
# Collecting tf-models-official
#   Downloading tf_models_official-2.6.0-py2.py3-none-any.whl (1.8 MB)
# Requirement already satisfied: matplotlib in ./jupyter-venv/lib/python3.8/site-packages/matplotlib-3.5.0b1-py3.8-linux-x86_64.egg (3.5.0b1)
# Requirement already satisfied: Cython in ./jupyter-venv/lib/python3.8/site-packages/Cython-3.0.0a9-py3.8-linux-x86_64.egg (3.0.0a9)
# Collecting gtts
#   Downloading gTTS-2.2.3-py3-none-any.whl (25 kB)
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
# Requirement already satisfied: jupyter-console in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (6.4.0)
# Requirement already satisfied: nbconvert in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (6.1.0)
# Requirement already satisfied: ipywidgets in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (7.6.5)
# Requirement already satisfied: qtconsole in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (5.1.1)
# Requirement already satisfied: ipykernel in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (6.4.1)
# Requirement already satisfied: notebook in ./jupyter-venv/lib/python3.8/site-packages (from jupyter) (6.4.4)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6
#   Downloading ibm-cloud-sdk-core-3.11.3.tar.gz (45 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./jupyter-venv/lib/python3.8/site-packages (from ibm-watson) (2.8.2)
# Collecting requests<3.0,>=2.0
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting websocket-client==1.1.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting wheel~=0.35
#   Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.18.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp38-cp38-manylinux2014_x86_64.whl (4.0 MB)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Collecting kaggle>=1.3.9
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
# Collecting psutil>=5.4.3
#   Downloading psutil-5.8.0-cp38-cp38-manylinux2010_x86_64.whl (296 kB)
# Collecting pandas>=0.22.0
#   Downloading pandas-1.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
# Requirement already satisfied: Pillow in ./jupyter-venv/lib/python3.8/site-packages/Pillow-8.3.2-py3.8-linux-x86_64.egg (from tf-models-official) (8.3.2)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.14.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting tf-slim>=1.1.0
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting gin-config
#   Downloading gin_config-0.4.0-py2.py3-none-any.whl (46 kB)
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.4.0-py3-none-any.whl (4.0 MB)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.7.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
# Collecting tensorflow-hub>=0.6.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Collecting tensorflow>=2.5.0
#   Downloading tensorflow-2.6.0-cp38-cp38-manylinux2010_x86_64.whl (458.4 MB)
# Collecting google-api-python-client>=1.6.7
#   Downloading google_api_python_client-2.22.0-py2.py3-none-any.whl (7.5 MB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.6.0-py2.py3-none-any.whl (211 kB)
# Collecting pycocotools
#   Downloading pycocotools-2.0.2.tar.gz (23 kB)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.3.56-cp38-cp38-manylinux2014_x86_64.whl (37.1 MB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
# Collecting tensorflow-text>=2.5.0
#   Downloading tensorflow_text-2.6.0-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
# Requirement already satisfied: cycler>=0.10 in ./jupyter-venv/lib/python3.8/site-packages/cycler-0.10.0-py3.8.egg (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./jupyter-venv/lib/python3.8/site-packages/fonttools-4.27.1-py3.8.egg (from matplotlib) (4.27.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jupyter-venv/lib/python3.8/site-packages/kiwisolver-1.3.2-py3.8-linux-x86_64.egg (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in ./jupyter-venv/lib/python3.8/site-packages (from matplotlib) (21.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jupyter-venv/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: setuptools-scm>=4 in ./jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg (from matplotlib) (6.3.2)
# Collecting click
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: pygments in ./jupyter-venv/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.10.0)
# Requirement already satisfied: ipython in ./jupyter-venv/lib/python3.8/site-packages (from jupyter-console->jupyter) (7.27.0)
# Requirement already satisfied: jupyter-client in ./jupyter-venv/lib/python3.8/site-packages (from jupyter-console->jupyter) (7.0.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./jupyter-venv/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.20)
# Requirement already satisfied: defusedxml in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: nbformat>=4.4 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (5.1.3)
# Requirement already satisfied: entrypoints>=0.2.2 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.3)
# Requirement already satisfied: jupyter-core in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (4.8.1)
# Requirement already satisfied: jinja2>=2.4 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (3.0.1)
# Requirement already satisfied: jupyterlab-pygments in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: bleach in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: testpath in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (0.5.0)
# Requirement already satisfied: traitlets>=5.0 in ./jupyter-venv/lib/python3.8/site-packages (from nbconvert->jupyter) (5.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in ./jupyter-venv/lib/python3.8/site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./jupyter-venv/lib/python3.8/site-packages (from ipywidgets->jupyter) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in ./jupyter-venv/lib/python3.8/site-packages (from ipywidgets->jupyter) (1.0.2)
# Requirement already satisfied: qtpy in ./jupyter-venv/lib/python3.8/site-packages (from qtconsole->jupyter) (1.11.1)
# Requirement already satisfied: pyzmq>=17.1 in ./jupyter-venv/lib/python3.8/site-packages (from qtconsole->jupyter) (22.3.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in ./jupyter-venv/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./jupyter-venv/lib/python3.8/site-packages (from ipykernel->jupyter) (1.4.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in ./jupyter-venv/lib/python3.8/site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: prometheus-client in ./jupyter-venv/lib/python3.8/site-packages (from notebook->jupyter) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in ./jupyter-venv/lib/python3.8/site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in ./jupyter-venv/lib/python3.8/site-packages (from notebook->jupyter) (0.12.1)
# Requirement already satisfied: argon2-cffi in ./jupyter-venv/lib/python3.8/site-packages (from notebook->jupyter) (21.1.0)
# Collecting PyJWT<3.0.0,>=2.0.1
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Using cached idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Using cached charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools>=41.0.0 in ./jupyter-venv/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (44.0.0)
# Collecting python-slugify
#   Downloading python_slugify-5.0.2-py2.py3-none-any.whl (6.7 kB)
# Collecting tqdm
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.12.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: attrs>=18.1.0 in ./jupyter-venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official) (21.2.0)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.2.0-py3-none-any.whl (48 kB)
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-5.2.2-py3-none-any.whl (27 kB)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.19.1-py3-none-any.whl (95 kB)
# Collecting pyasn1>=0.1.7
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules>=0.0.5
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Collecting keras~=2.6
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Collecting google-api-core<3.0.0dev,>=1.21.0
#   Downloading google_api_core-2.0.1-py2.py3-none-any.whl (92 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Collecting dm-tree~=0.1.1
#   Downloading dm_tree-0.1.6-cp38-cp38-manylinux2014_x86_64.whl (116 kB)
# Collecting scikit-learn>=0.21.3
#   Downloading scikit_learn-1.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.8 MB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting regex
#   Downloading regex-2021.9.24-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: tomli>=1.0.0 in ./jupyter-venv/lib/python3.8/site-packages/tomli-1.2.1-py3.8.egg (from setuptools-scm>=4->matplotlib) (1.2.1)
# Requirement already satisfied: decorator in ./jupyter-venv/lib/python3.8/site-packages (from ipython->jupyter-console->jupyter) (5.1.0)
# Requirement already satisfied: pickleshare in ./jupyter-venv/lib/python3.8/site-packages (from ipython->jupyter-console->jupyter) (0.7.5)
# Requirement already satisfied: backcall in ./jupyter-venv/lib/python3.8/site-packages (from ipython->jupyter-console->jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./jupyter-venv/lib/python3.8/site-packages (from ipython->jupyter-console->jupyter) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in ./jupyter-venv/lib/python3.8/site-packages (from ipython->jupyter-console->jupyter) (0.18.0)
# Requirement already satisfied: nest-asyncio>=1.5 in ./jupyter-venv/lib/python3.8/site-packages (from jupyter-client->jupyter-console->jupyter) (1.5.1)
# Requirement already satisfied: wcwidth in ./jupyter-venv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./jupyter-venv/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./jupyter-venv/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert->jupyter) (2.0.1)
# Requirement already satisfied: webencodings in ./jupyter-venv/lib/python3.8/site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in ./jupyter-venv/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in ./jupyter-venv/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter) (1.14.6)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting zipp>=3.1.0; python_version < "3.10"
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./jupyter-venv/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter-console->jupyter) (0.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./jupyter-venv/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter) (0.18.0)
# Requirement already satisfied: pycparser in ./jupyter-venv/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter) (2.20)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: ibm-watson, playsound, ibm-cloud-sdk-core, wrapt, termcolor, kaggle, py-cpuinfo, pycocotools, seqeval, promise, future, clang
#   Building wheel for ibm-watson (PEP 517): started
#   Building wheel for ibm-watson (PEP 517): finished with status 'done'
#   Created wheel for ibm-watson: filename=ibm_watson-5.3.0-py3-none-any.whl size=408872 sha256=ef29e8aa600407033c1f3ccda397d969c0070805cfe40f96e6cc7a83620955e3
#   Stored in directory: /home/dishant/.cache/pip/wheels/79/7c/1e/3fc8483af029cd8cb8c803eeaf282cbeb60724130d9dca4b83
#   Building wheel for playsound (setup.py): started
#   Building wheel for playsound (setup.py): finished with status 'error'
#   Running setup.py clean for playsound
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/playsound/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/playsound/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-zmrrx8_q
#        cwd: /tmp/pip-install-5i6gjmc5/playsound/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for playsound
#   Building wheel for ibm-cloud-sdk-core (setup.py): started
#   Building wheel for ibm-cloud-sdk-core (setup.py): finished with status 'error'
#   Running setup.py clean for ibm-cloud-sdk-core
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/ibm-cloud-sdk-core/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/ibm-cloud-sdk-core/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-m0htdyht
#        cwd: /tmp/pip-install-5i6gjmc5/ibm-cloud-sdk-core/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for ibm-cloud-sdk-core
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'error'
#   Running setup.py clean for wrapt
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/wrapt/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/wrapt/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-woxlx1us
#        cwd: /tmp/pip-install-5i6gjmc5/wrapt/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for wrapt
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'error'
#   Running setup.py clean for termcolor
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/termcolor/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/termcolor/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-5tn1axqw
#        cwd: /tmp/pip-install-5i6gjmc5/termcolor/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for termcolor
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'error'
#   Running setup.py clean for kaggle
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/kaggle/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/kaggle/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-cj0mopve
#        cwd: /tmp/pip-install-5i6gjmc5/kaggle/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for kaggle
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'error'
#   Running setup.py clean for py-cpuinfo
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/py-cpuinfo/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/py-cpuinfo/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-ghqdi9w3
#        cwd: /tmp/pip-install-5i6gjmc5/py-cpuinfo/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for py-cpuinfo
#   Building wheel for pycocotools (setup.py): started
#   Building wheel for pycocotools (setup.py): finished with status 'error'
#   Running setup.py clean for pycocotools
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/pycocotools/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/pycocotools/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-u1jn8vfa
#        cwd: /tmp/pip-install-5i6gjmc5/pycocotools/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for pycocotools
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'error'
#   Running setup.py clean for seqeval
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/seqeval/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/seqeval/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-2nk_sau9
#        cwd: /tmp/pip-install-5i6gjmc5/seqeval/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for seqeval
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'error'
#   Running setup.py clean for promise
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/promise/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/promise/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-o0x7wg5c
#        cwd: /tmp/pip-install-5i6gjmc5/promise/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for promise
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'error'
#   Running setup.py clean for future
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/future/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/future/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-kkflag7j
#        cwd: /tmp/pip-install-5i6gjmc5/future/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for future
#   Building wheel for clang (setup.py): started
#   Building wheel for clang (setup.py): finished with status 'error'
#   Running setup.py clean for clang
#   ERROR: Command errored out with exit status 1:
#    command: /home/dishant/auto-annotation/jupyter-venv/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-5i6gjmc5/clang/setup.py'"'"'; __file__='"'"'/tmp/pip-install-5i6gjmc5/clang/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-dm39o_l0
#        cwd: /tmp/pip-install-5i6gjmc5/clang/
#   Complete output (28 lines):
#   /home/dishant/auto-annotation/jupyter-venv/lib/python3.8/site-packages/setuptools_scm-6.3.2-py3.8.egg/setuptools_scm/integration.py:16: RuntimeWarning:
#   ERROR: setuptools==44.0.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for clang
# Successfully built ibm-watson
# Failed to build playsound ibm-cloud-sdk-core wrapt termcolor kaggle py-cpuinfo pycocotools seqeval promise future clang
# ERROR: tensorflow-metadata 1.2.0 has requirement absl-py<0.13,>=0.9, but you'll have absl-py 0.14.0 which is incompatible.
# ERROR: tensorflow 2.6.0 has requirement grpcio<2.0,>=1.37.0, but you'll have grpcio 1.34.1 which is incompatible.
# ERROR: tensorflow 2.6.0 has requirement tensorflow-estimator~=2.6, but you'll have tensorflow-estimator 2.5.0 which is incompatible.
# Installing collected packages: PyJWT, certifi, idna, charset-normalizer, urllib3, requests, ibm-cloud-sdk-core, websocket-client, ibm-watson, wrapt, keras-nightly, six, absl-py, gast, numpy, keras-preprocessing, wheel, google-pasta, typing-extensions, astunparse, opt-einsum, protobuf, flatbuffers, termcolor, tensorflow-estimator, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, tensorboard-plugin-wit, markdown, werkzeug, grpcio, tensorboard-data-server, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, h5py, tensorflow-gpu, pyyaml, text-unidecode, python-slugify, tqdm, kaggle, psutil, pytz, pandas, py-cpuinfo, typeguard, tensorflow-addons, tf-slim, gin-config, googleapis-common-protos, tensorflow-metadata, zipp, importlib-resources, promise, dill, future, tensorflow-datasets, httplib2, oauth2client, scipy, tensorflow-hub, clang, keras, tensorflow, google-api-core, google-auth-httplib2, uritemplate, google-api-python-client, sentencepiece, dm-tree, tensorflow-model-optimization, pycocotools, joblib, threadpoolctl, scikit-learn, seqeval, opencv-python-headless, portalocker, colorama, regex, tabulate, sacrebleu, tensorflow-text, tf-models-official, click, gtts, playsound
#     Running setup.py install for ibm-cloud-sdk-core: started
#     Running setup.py install for ibm-cloud-sdk-core: finished with status 'done'
#     Running setup.py install for wrapt: started
#     Running setup.py install for wrapt: finished with status 'done'
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#     Running setup.py install for termcolor: started
#     Running setup.py install for termcolor: finished with status 'done'
#     Running setup.py install for kaggle: started
#     Running setup.py install for kaggle: finished with status 'done'
#     Running setup.py install for py-cpuinfo: started
#     Running setup.py install for py-cpuinfo: finished with status 'done'
#     Running setup.py install for promise: started
#     Running setup.py install for promise: finished with status 'done'
#     Running setup.py install for future: started
#     Running setup.py install for future: finished with status 'done'
#     Running setup.py install for clang: started
#     Running setup.py install for clang: finished with status 'done'
#     Running setup.py install for pycocotools: started
#     Running setup.py install for pycocotools: finished with status 'done'
#     Running setup.py install for seqeval: started
#     Running setup.py install for seqeval: finished with status 'done'
#     Running setup.py install for playsound: started

# %%
PATH_TO_LABELS = 'models/research/object_detection/data/mscoco_label_map.pbtxt'

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
import pathlib

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_86298/2686676708.py in <module>
#       4 import sys
#       5 import tarfile
# ----> 6 import tensorflow as tf
#       7 import zipfile
#       8 import pathlib
#
# ModuleNotFoundError: No module named 'tensorflow'
